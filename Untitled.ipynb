# %%
from data_loader import compute_final_data_2022
compute_final_data_2022(save=True)
# Out:
# Started computing final dataset for years 2022 and onwards.
# Failed to load the burglary count data from ./data/burglary-count.csv
# Started computing burglary counts.
# Failed to load the crime data from ./data/metropolitan-burglary-combined.csv
# Started combining crime data.
# Failed to extract crime for 2010-12.
# Failed to extract crime for 2011-01.
# Failed to extract crime for 2011-02.
# Failed to extract crime for 2011-03.
# Failed to extract crime for 2011-04.
# Failed to extract crime for 2011-05.
# Failed to extract crime for 2011-06.
# Failed to extract crime for 2011-07.
# Failed to extract crime for 2011-08.
# Failed to extract crime for 2011-09.
# Failed to extract crime for 2011-10.
# Failed to extract crime for 2011-11.
# Failed to extract crime for 2011-12.
# Failed to extract crime for 2012-01.
# Failed to extract crime for 2012-02.
# Failed to extract crime for 2012-03.
# Failed to extract crime for 2012-04.
# Failed to extract crime for 2012-05.
# ...

# %%
from data_loader import load_final_data_2022
df = load_final_data_2022()
df
# Out:
# Failed to load the final data 2022 from ./data/final-data-2022.csv
# Started computing final dataset for years 2022 and onwards.
# Failed to load the burglary count data from ./data/burglary-count.csv
# Started computing burglary counts.
# Failed to load the crime data from ./data/metropolitan-burglary-combined.csv
# Started combining crime data.
# Failed to extract crime for 2010-12.
# Failed to extract crime for 2011-01.
# Failed to extract crime for 2011-02.
# Failed to extract crime for 2011-03.
# Failed to extract crime for 2011-04.
# Failed to extract crime for 2011-05.
# Failed to extract crime for 2011-06.
# Failed to extract crime for 2011-07.
# Failed to extract crime for 2011-08.
# Failed to extract crime for 2011-09.
# Failed to extract crime for 2011-10.
# Failed to extract crime for 2011-11.
# Failed to extract crime for 2011-12.
# Failed to extract crime for 2012-01.
# Failed to extract crime for 2012-02.
# Failed to extract crime for 2012-03.
# ...
